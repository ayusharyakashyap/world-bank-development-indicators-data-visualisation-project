# %%
import pandas as pd
import numpy as np
import os

# %%
# Load the dataset
file_path = '/Users/ayusharyakashyap/Desktop/Semester 5/Data Visualization/A1 Project/world_bank_development_indicators.csv'
df = pd.read_csv(file_path)

# %%
# Convert the 'Year' column to datetime format if necessary
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

# Extract rows with the country name "Ukraine" and from the year 1989 onwards
sri_lanka_data = df[(df['country'].str.startswith('Sri Lanka')) & (df['date'].dt.year >= 1961)]

# Save the new dataset to a CSV file
sri_lanka_data.to_csv('/Users/ayusharyakashyap/Desktop/Semester 5/Data Visualization/A1 Project/Sri_Lanka_data.csv', index=False)

# Display the first few rows of the new dataset
print(sri_lanka_data)

'''

1. Political Instability and Governance Issues:
Civil War: Sri Lanka experienced a prolonged civil war (1983-2009) which led to instability in its economy. During this period, government spending was high on defense, affecting fiscal policies and creating inflationary pressures.
Political Instability: Periodic political instability and changes in leadership have disrupted economic policies, leading to uncertainty and fluctuating inflation rates.
2. External Shocks:
Global Oil Prices: Sri Lanka is heavily reliant on oil imports. Fluctuations in global oil prices have had a significant impact on inflation. When oil prices rise, transportation and production costs increase, leading to inflationary pressures.
Commodity Prices: Sri Lanka is also an exporter of commodities such as tea and rubber. Fluctuations in global commodity prices, which affect the country's export earnings, lead to volatility in foreign exchange reserves and affect inflation.
3. Exchange Rate Volatility:
Currency Depreciation: Sri Lanka has faced periods of currency depreciation, especially during economic crises. A weak currency leads to higher import costs, contributing to inflation, particularly in a country reliant on imports for essential goods like fuel and food.
Foreign Debt: Sri Lanka’s reliance on foreign loans has led to external debt servicing issues. When the local currency depreciates, the cost of servicing debt in foreign currency increases, creating inflationary pressures.
4. Monetary Policy:
Loose Monetary Policies: At times, the central bank has adopted expansionary monetary policies, such as lowering interest rates and increasing the money supply, which can drive inflation. Conversely, tighter policies have been implemented in other periods to control inflation.
Debt Financing: Sri Lanka’s government has often resorted to financing its deficits through borrowing, which can lead to inflationary pressures, especially if the central bank prints money to cover government deficits.
5. Supply Chain Disruptions and Domestic Factors:
Agricultural Dependency: Sri Lanka's economy has a large agricultural component, making it vulnerable to natural disasters (like droughts and floods) that can disrupt food supply, leading to food inflation.
COVID-19 Pandemic: During the pandemic, supply chain disruptions and lockdowns created shortages of goods, which led to inflationary pressures in 2020-2021.
2022 Economic Crisis: In recent years, Sri Lanka has faced a severe economic crisis due to mismanagement of foreign reserves, debt defaults, and a lack of foreign currency for essential imports. This led to skyrocketing inflation, especially in 2022, with shortages of basic goods like food and fuel.
6. External Financial Aid and IMF Involvement:
Sri Lanka has often relied on IMF interventions and external financial aid to stabilize its economy during crises. However, the structural adjustments that come with these packages sometimes lead to short-term inflationary pressures (e.g., devaluation of currency, austerity measures).
7. Import Dependency:
Sri Lanka is heavily reliant on imports for essential goods, such as food, fuel, and medicine. Any external shock or disruption in global trade (e.g., due to crises like the COVID-19 pandemic or the 2022 Russian invasion of Ukraine) leads to an increase in import prices, contributing to inflation spikes.
                                                                                                                                                                                                                                                                              
'''
# Out:
#          country       date  agricultural_land%  forest_land%  land_area  \
# 14492  Sri Lanka 1961-01-01           27.475682           NaN   62710.00
# 14493  Sri Lanka 1962-01-01           27.220539           NaN   62710.00
# 14494  Sri Lanka 1963-01-01           32.849625           NaN   62710.00
# 14495  Sri Lanka 1964-01-01           33.535321           NaN   62710.00
# 14496  Sri Lanka 1965-01-01           34.380482           NaN   62710.00
# ...          ...        ...                 ...           ...        ...
# 14550  Sri Lanka 2019-01-01           45.447295     34.206710   61864.47
# 14551  Sri Lanka 2020-01-01           45.457485     34.158099   61860.00
# 14552  Sri Lanka 2021-01-01           45.457485     34.107016   61860.00
# 14553  Sri Lanka 2022-01-01                 NaN           NaN        NaN
# 14554  Sri Lanka 2023-01-01                 NaN           NaN        NaN
#
#        avg_precipitation  trade_in_services%  control_of_corruption_estimate  \
# ...

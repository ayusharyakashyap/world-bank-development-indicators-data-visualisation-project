# %%
import pandas as pd
import numpy as np
import os

# %%
# Load the dataset
file_path = '/Users/ayusharyakashyap/Desktop/Semester 5/Data Visualization/A1 Project/Filtered CSV/world_development_indicators_new_columns.csv'
df = pd.read_csv(file_path)

# %%
# Convert 'date' column to datetime if it's not already in datetime format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Extract the year from the 'date' column
df['year'] = df['date'].dt.year

# Filter the DataFrame for the year 2002
df_filtered = df[df['year'].isin([2002])]

# Display the filtered data
print(df_filtered)

# Optional: If you want to save the filtered data to a CSV
df_filtered.to_csv('/Users/ayusharyakashyap/Desktop/Semester 5/Data Visualization/A1 Project/data_gdp_growth_2002.csv', index=False)
# Out:
#                            country       date  agricultural_land%  \
# 42                     Afghanistan 2002-01-01           57.939684
# 106    Africa Eastern and Southern 2002-01-01           44.636051
# 170     Africa Western and Central 2002-01-01           37.290881
# 234                        Albania 2002-01-01           41.605839
# 298                        Algeria 2002-01-01           16.733565
# ...                            ...        ...                 ...
# 16994           West Bank and Gaza 2002-01-01           77.870947
# 17058                        World 2002-01-01           37.475004
# 17122                  Yemen, Rep. 2002-01-01           44.805576
# 17186                       Zambia 2002-01-01           30.422793
# 17250                     Zimbabwe 2002-01-01           39.989660
#
#        forest_land%     land_area  avg_precipitation  trade_in_services%  \
# 42         1.852782  6.522300e+05              327.0                 NaN
# ...

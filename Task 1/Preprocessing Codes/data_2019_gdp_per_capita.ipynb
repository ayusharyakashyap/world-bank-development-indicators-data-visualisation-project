# %%
import pandas as pd
import numpy as np
import os

# %%
# Load the dataset
file_path = '/Users/ayusharyakashyap/Desktop/Semester 5/Data Visualization/A1 Project/Filtered CSV/world_bank_development_indicators_with_gdp_per_capita.csv'
df = pd.read_csv(file_path)

# %%
# Convert 'date' column to datetime if it's not already in datetime format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Extract the year from the 'date' column
df['year'] = df['date'].dt.year

# Filter the DataFrame for the year 2019
df_filtered = df[df['year'].isin([2019])]

# Display the filtered data
print(df_filtered)

# Optional: If you want to save the filtered data to a CSV
df_filtered.to_csv('/Users/ayusharyakashyap/Desktop/Semester 5/Data Visualization/A1 Project/data_2019_gdp_per_capita.csv', index=False)
# Out:
#                            country       date  agricultural_land%  \
# 39                     Afghanistan 2019-01-01           58.276988
# 101    Africa Eastern and Southern 2019-01-01           46.419375
# 164     Africa Western and Central 2019-01-01           40.097389
# 203                        Albania 2019-01-01           42.846715
# 266                        Algeria 2019-01-01           17.347004
# ...                            ...        ...                 ...
# 12948        Virgin Islands (U.S.) 2019-01-01            9.428571
# 12976           West Bank and Gaza 2019-01-01           70.652375
# 13039                        World 2019-01-01           36.762648
# 13131                       Zambia 2019-01-01           32.067959
# 13194                     Zimbabwe 2019-01-01           41.876696
#
#        forest_land%     land_area  avg_precipitation  trade_in_services%  \
# 39         1.852782  6.522300e+05              327.0            9.918134
# ...
